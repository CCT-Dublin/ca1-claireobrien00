# %%
import pandas as pd
import numpy as np
import statistics as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Attractions_df = pd.read_csv('Attractions.csv') #Reading in the CSV file

# %% [markdown]
# # Exploring the data

# %%
Attractions_df.head(10)
# Out:
#    _id                                 Name
# 0  NaN                                  NaN  \
# 1  1.0                         Dunmore Cave
# 2  2.0                         Liberty Tree
# 3  3.0   Clonea Strand Blue Flag Beach 2019
# 4  4.0                             Dublinia
# 5  5.0                  St. Audoen's Church
# 6  6.0      Dalkey Castle & Heritage Centre
# 7  7.0        Slieve League Cultural Centre
# 8  8.0  Shackleton Outdoor Education Centre
# 9  9.0              The Trinity Tree Dingle
#
#                                                  Url         Telephone
# 0                                                NaN               NaN  \
# 1  http://www.heritageireland.ie/en/south-east/du...  +353(0)567767726
# 2                                                NaN  +353(0)599130411
# 3                    http://www.blueflagireland.org/               NaN
# 4            https://www.facebook.com/dubliniaviking   +353(0)16794611
# ...

# %%
Attractions_df.shape
# Out:
# (2022, 10)

# %%
Attractions_df['Tags'].value_counts().head(10)
# Out:
# Tags
# Museums and Attraction                                                                                             317
# Historic Houses and Castle,Castle                                                                                  191
# Gardening,Nature and Wildlife,Gardens,Garden                                                                       167
# Beach                                                                                                              158
# Discovery Point                                                                                                    158
# Church Abbey,Monastery,Churches,Abbeys and Monastery                                                               157
# Learning,Museums and Attraction                                                                                    118
# Craft,Shopping,Learning,Museums and Attraction                                                                     103
# ...

# %%
Attractions_df['AddressRegion'].value_counts()
# Out:
# AddressRegion
# Dublin       279
# Cork         243
# Kerry        167
# Donegal      159
# Galway       153
# Mayo         120
# Clare        114
# Wexford       97
# Waterford     73
# Sligo         62
# Wicklow       60
# Tipperary     59
# Limerick      58
# Kilkenny      57
# Carlow        43
# Meath         42
# Kildare       39
# Louth         36
# Roscommon     30
# Laois         22
# Cavan         20
# Offaly        19
# Westmeath     18
# Leitrim       16
# Monaghan      12
# Longford       9
# KILKENNY       1
# Name: count, dtype: int64

# %%
print(Attractions_df.isnull().sum()) #a lot of missing data
# Out:
# _id                  1
# Name                 1
# Url                340
# Telephone          425
# Longitude            1
# Latitude             1
# AddressRegion       14
# AddressLocality    618
# AddressCountry       1
# Tags                 1
# dtype: int64

# %%
#Going to drop URL and Telephone columns as they won't be used 
Attractions_df.drop(columns=['Url'], inplace=True)
Attractions_df.drop(columns=['Telephone'], inplace=True)

# %%
Attractions_df["AddressRegion"].unique()
# Out:
# array([nan, 'Kilkenny', 'Carlow', 'Waterford', 'Dublin', 'Donegal',
#        'Kerry', 'Clare', 'Cork', 'Kildare', 'Galway', 'Mayo', 'Wexford',
#        'Longford', 'Limerick', 'Sligo', 'Wicklow', 'Meath', 'Offaly',
#        'Cavan', 'Roscommon', 'Monaghan', 'Tipperary', 'Louth', 'Laois',
#        'Leitrim', 'Westmeath', 'KILKENNY'], dtype=object)

# %%
#Top 5 tags
options = ['Museums and Attraction', 'Historic Houses and Castle,Castle' ,' Gardening,Nature and Wildlife,Gardens,Garden', 'Beach', 'Discovery Point']
Attractions_df = Attractions_df[Attractions_df['Tags'].isin(options)]
Attractions_df.head(50)
# Out:
#        _id                                               Name  Longitude
# 3      3.0                 Clonea Strand Blue Flag Beach 2019  -7.542846  \
# 4      4.0                                           Dublinia  -6.272000
# 6      6.0                    Dalkey Castle & Heritage Centre  -6.105461
# 7      7.0                      Slieve League Cultural Centre  -8.641766
# 17    17.0                        The Irish Pewtermill Centre  -6.809468
# 19    19.0  Ballinskelligs Beach Blue Flag and Green Coast... -10.271571
# 20    20.0             Ballybunion North Blue flag Beach 2019  -9.681072
# 21    21.0             Ballybunion South Blue Flag Beach 2019  -9.684991
# 22    22.0                   Ballyheigue Blue Flag Beach 2019  -9.833328
# 23    23.0                         Banna Blue Flag Beach 2019  -9.837115
# 24    24.0                                    Kilmurvey Beach  -9.764792
# 25    25.0                     Derrynane Blue Flag Beach 2019 -10.134490
# ...

# %%
Attractions_df['Tags'].value_counts()
# Out:
# Tags
# Museums and Attraction               317
# Historic Houses and Castle,Castle    191
# Beach                                158
# Discovery Point                      158
# Name: count, dtype: int64

# %%
Attractions_df.shape
# Out:
# (824, 8)

# %%
print(Attractions_df.isnull().sum())
# Out:
# _id                  0
# Name                 0
# Longitude            0
# Latitude             0
# AddressRegion        3
# AddressLocality    246
# AddressCountry       0
# Tags                 0
# dtype: int64
